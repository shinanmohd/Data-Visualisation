# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
studentperformance=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib/docs/StudentsPerformance.csv')

# %%
studentperformance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## Description

# %%
# gender: Categorical variable indicating student gender (e.g., male, female).
# race/ethnicity: Categorical variable representing student racial or ethnic background.
# parental level of education: Categorical variable showing highest education level of parents.
# lunch: Categorical variable indicating type of lunch (standard or free/reduced).
# test preparation course: Categorical variable indicating completion of a test prep course (yes/no).
# math score: Numerical score (0-100) reflecting student performance in math.
# reading score: Numerical score (0-100) reflecting student performance in reading.
# writing score: Numerical score (0-100) reflecting student performance in writing.

# %%
studentperformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
studentperformance.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
studentperformance.duplicated().sum()
# Out:
# 0

# %%
studentperformance.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
studentperformance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
studentperformance.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
studentperformance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# ## Heatmap representation

# %%
studperf=studentperformance.select_dtypes(include='number')

# %%
sns.heatmap(studperf.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## representing counts of each group using countplot

# %%
sns.countplot(x='race/ethnicity',data=studentperformance);

# %% [markdown]
# ## student performane representation using lineplot

# %%
sns.lineplot(x='reading score',y='writing score',data=studentperformance,marker='s')
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='reading score',y='writing score',hue='test preparation course',data=studentperformance)
plt.title('Student Performance');

# %% [markdown]
# ## representing writing score of each group with the highest qualification each achieved

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='race/ethnicity',y='writing score',hue='parental level of education',data=studentperformance)
plt.title('writing score of each group with the highest qualification');

# %% [markdown]
# ## checking if their any outliers using boxplot

# %%
sns.boxplot(studentperformance)
# Out:
# <Axes: >

# %% [markdown]
# ## comparing students reading score with writing score using scatter plot

# %%
sns.scatterplot(x='reading score',y='writing score',data=studentperformance,hue='race/ethnicity');

# %% [markdown]
# ## which group has a high score in maths using violineplot

# %%
sns.violinplot(x='race/ethnicity',y='math score',data=studentperformance);

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(studentperformance);

# %% [markdown]
# ## jionplot

# %%
sns.jointplot(x='reading score',y='writing score',data=studentperformance,kind='scatter');

# %% [markdown]
# ## facetgrid

# %%
f=sns.FacetGrid(data=studentperformance,row='race/ethnicity',col='parental level of education')
f.map(sns.kdeplot,'math score')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## piechart reprensting which group has high score in maths

# %%
studentperformance.groupby('race/ethnicity')['math score'].sum().plot(kind='pie',explode=(0,0,.1,0,0),shadow=True,autopct="%1.2f%%");

# %%
sns.histplot(x='race/ethnicity',data=studentperformance);
