# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
games=pd.read_csv(r'C:\Users\hp\Data Analyst\csv\Online_game.csv')

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Description
#
# * This dataset appears to represent video game sales data, containing information about 16,598 video games.
# * Each row corresponds to a specific video game, and the dataset includes the following columns
#    * Rank: A unique integer identifier that ranks the video games based on a specific criterion (likely sales    * Name: The name of the video ga
#     * Platform: The gaming platform on which the video game was released (e.g., PS4, Xbox One,
#     * Year: The ye game was released. This column has some missing values, with 16,327 non-null entries out of 16,598.
#     * Genre: The genre of the video game (e.g., Action, Sports, RPG).
#     * Publisher: The company that published the video game. There are a few missing values, with 16,540 non-null entries.
#     * NA_Sales: Sales in North America, measured in millions of units.
#     * EU_Sales: Sales in Europe, measured in millions of units.
#     * JP_Sales: Sales in Japan, measured in millions of units.
#     *
# Other_Sales: Sales in regions other than North America, Europe, and Japan, measured in millions of units.
#     * Global_Sales: The total global sales of the video game, measured in millions of units.ar the

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
games.fillna(0,inplace=True)

# %%
games.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
games.duplicated().sum()
# Out:
# 0

# %%
games.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   1973.647307      0.264667      0.146652      0.077782
# std     4791.853933    254.346809      0.816683      0.505351      0.309291
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
games.describe().T
# Out:
#                 count         mean          std   min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933  1.00  4151.25  8300.50
# Year          16598.0  1973.647307   254.346809  0.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683  0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351  0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291  0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588  0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028  0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        0, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %% [markdown]
# ## -Q1Retrieve the details of nintendo publishers

# %%
nint=games[games['Publisher']=='Nintendo']
nint
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games[games['Publisher'(games['Global_Sales'].max())
# Out:
#   Cell In[86], line 1
#     games[games['Publisher'].where(games['Global_Sales'].max())
#                                                                ^
# SyntaxError: incomplete input

# %% [markdown]
# ## -Q2retrieve the games that is developed by nintendo

# %%
nint['Name'].unique()
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii',
#        'Wii Sports Resort', 'Pokemon Red/Pokemon Blue', 'Tetris',
#        'New Super Mario Bros.', 'Wii Play', 'New Super Mario Bros. Wii',
#        'Duck Hunt', 'Nintendogs', 'Mario Kart DS',
#        'Pokemon Gold/Pokemon Silver', 'Wii Fit', 'Wii Fit Plus',
#        'Super Mario World',
#        'Brain Age: Train Your Brain in Minutes a Day',
#        'Pokemon Diamond/Pokemon Pearl', 'Super Mario Land',
#        'Super Mario Bros. 3', 'Pokemon Ruby/Pokemon Sapphire',
#        'Pokemon Black/Pokemon White',
#        'Brain Age 2: More Training in Minutes a Day',
#        'Pokémon Yellow: Special Pikachu Edition', 'Pokemon X/Pokemon Y',
#        'Super Smash Bros. Brawl', 'Animal Crossing: Wild World',
#        'Mario Kart 7', 'Pokemon HeartGold/Pokemon SoulSilver',
#        'Super Mario 64', 'Super Mario Galaxy',
#        'Pokemon Omega Ruby/Pokemon Alpha Sapphire',
# ...

# %%
nint['Name']
# Out:
# 0                                               Wii Sports
# 1                                        Super Mario Bros.
# 2                                           Mario Kart Wii
# 3                                        Wii Sports Resort
# 4                                 Pokemon Red/Pokemon Blue
#                                ...
# 16269                             Slide Adventure: Mag Kid
# 16357                 Mario vs. Donkey Kong: Tipping Stars
# 16456                             Art Academy: Home Studio
# 16473                                      Captain Rainbow
# 16542    Mario & Luigi: Paper Jam & Mario Kart 7 Double...
# Name: Name, Length: 703, dtype: object

# %% [markdown]
# ## -Q3publisher with highest sale in  global

# %%
games.groupby(['Publisher'])['Global_Sales'].max().idxmax()
# Out:
# 'Nintendo'

# %%
games.groupby(['Publisher'])['Global_Sales'].max().sort_values(ascending=False).idxmax()
# Out:
# 'Nintendo'

# %% [markdown]
# ## -Q4In which region the publisher nintendo has high sales

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
high=games.groupby(['Publisher'])

# %%
high=high.get_group('Nintendo')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_716\2118574242.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   high=high.get_group('Nintendo')

# %%
high
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
high[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].max()
# Out:
# NA_Sales       41.49
# EU_Sales       29.02
# JP_Sales       10.22
# Other_Sales     8.46
# dtype: float64

# %%
high[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].max().idxmax()
# Out:
# 'NA_Sales'

# %% [markdown]
# ## -Q5Retrieve the game that has highest sale in 2010

# %%
games['Year']=games['Year'].astype('int64')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16598 non-null  int64
#  4   Genre         16598 non-null  object
#  5   Publisher     16598 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
highgame=games.groupby(['Year'])

# %%
highgame

# %%
highgame=highgame.get_group(2010)
highgame
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_716\2972908449.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   highgame=highgame.get_group(2010)
#         Rank                                               Name Platform  \
# 15        16                                 Kinect Adventures!     X360
# 26        27                        Pokemon Black/Pokemon White       DS
# 31        32                            Call of Duty: Black Ops     X360
# 40        41                            Call of Duty: Black Ops      PS3
# 54        55                                     Gran Turismo 5      PS3
# ...      ...                                                ...      ...
# 16437  16440              The Cages: Pro Style Batting Practice      Wii
# 16478  16481                 Ishin no Arashi: Shippuu Ryuumeden       DS
# ...

# %%
highgame=highgame.groupby(['Name'])

# %%
highgame[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].max().idxmax()
# Out:
# NA_Sales                Kinect Adventures!
# EU_Sales                Kinect Adventures!
# JP_Sales       Pokemon Black/Pokemon White
# Other_Sales                 Gran Turismo 5
# dtype: object

# %%
highgame['Global_Sales'].max().idxmax()
# Out:
# 'Kinect Adventures!'

# %% [markdown]
# ## Q6Retrive the games name and publisher with genre is shooter

# %%
genre=games.groupby(['Genre'])

# %%
genre=genre.get_group('Shooter')
genre
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_716\220463387.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   genre=genre.get_group('Shooter')
#         Rank                                               Name Platform  \
# 9         10                                          Duck Hunt      NES
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# ...      ...                                                ...      ...
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16569  16572                                 Resident Evil 4 HD     XOne
# ...

# %%
genre[['Name','Publisher','Genre']]
# Out:
#                                                     Name    Publisher    Genre
# 9                                              Duck Hunt     Nintendo  Shooter
# 29                        Call of Duty: Modern Warfare 3   Activision  Shooter
# 31                               Call of Duty: Black Ops   Activision  Shooter
# 33                             Call of Duty: Black Ops 3   Activision  Shooter
# 34                            Call of Duty: Black Ops II   Activision  Shooter
# ...                                                  ...          ...      ...
# 16501  Transformers: War for Cybertron (XBox 360, PS3...   Activision  Shooter
# 16569                                 Resident Evil 4 HD       Capcom  Shooter
# 16577                                          Damnation  Codemasters  Shooter
# 16585                                             Breach    Destineer  Shooter
# 16594                      Men in Black II: Alien Escape   Infogrames  Shooter
#
# [1310 rows x 3 columns]

# %% [markdown]
# ## Q7List out the racing game that is published by Sony Computer Entertainment

# %%
race=games.groupby(['Genre'])

# %%
race=race.get_group('Racing')
race
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_716\3604274133.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   race=race.get_group('Racing')
#         Rank                                               Name Platform  \
# 2          3                                     Mario Kart Wii      Wii
# 11        12                                      Mario Kart DS       DS
# 28        29                             Gran Turismo 3: A-Spec      PS2
# 42        43                                       Mario Kart 7      3DS
# 47        48                                     Gran Turismo 4      PS2
# ...      ...                                                ...      ...
# 16530  16533                           Sébastien Loeb Rally Evo     XOne
# 16543  16546                             Driving Simulator 2011       PC
# ...

# %%
race[race['Publisher']=='Sony Computer Entertainment']
# Out:
#         Rank                                Name Platform  Year   Genre  \
# 28        29              Gran Turismo 3: A-Spec      PS2  2001  Racing
# 47        48                      Gran Turismo 4      PS2  2004  Racing
# 52        53                        Gran Turismo       PS  1997  Racing
# 54        55                      Gran Turismo 5      PS3  2010  Racing
# 69        70                      Gran Turismo 2       PS  1999  Racing
# ...      ...                                 ...      ...   ...     ...
# 12820  12822  MotoGP 4 - Official Game of MotoGP      PS2  2005  Racing
# 13002  13004              Ferrari F355 Challenge      PS2  2002  Racing
# 13893  13895   WRC: FIA World Rally Championship      PSP  2005  Racing
# 13997  13999                        Formula 1 06      PS2  2006  Racing
# 14166  14168                              MotoGP      PSP  2006  Racing
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Q8 retrieve the average of global sales of nintendo publishers

# %%
pub=games.groupby(['Publisher'])

# %%
pubgl=pub.get_group('Nintendo')
pubgl
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10700\4100238662.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   pubgl=pub.get_group('Nintendo')
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# ...

# %%
pubgl['Global_Sales'].mean()
# Out:
# 2.541337126600285

# %% [markdown]
# ### Q9 retrieve the platform with highest globalsales

# %%
games.nlargest(1,'Global_Sales')
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %% [markdown]
# ### Q10 retrieve the details of the lowest globalsales in 2008

# %%
year=games.groupby(['Year'])

# %%
year_2008=year.get_group(2008)
year_2008
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10700\728377944.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   year_2008=year.get_group(2008)
#         Rank                                              Name Platform  \
# 2          3                                    Mario Kart Wii      Wii
# 39        40                           Super Smash Bros. Brawl      Wii
# 51        52                               Grand Theft Auto IV     X360
# 56        57                               Grand Theft Auto IV      PS3
# 88        89                          Pokémon Platinum Version       DS
# ...      ...                                               ...      ...
# 16575  16578                             Neo Angelique Special      PSP
# 16580  16583                                         Real Rode      PS2
# ...

# %%
year_2008.nsmallest(1,"Global_Sales")
# Out:
#         Rank   Name Platform    Year   Genre   Publisher  NA_Sales  EU_Sales  \
# 15980  15983  Turok       PC  2008.0  Action  Touchstone       0.0      0.01
#
#        JP_Sales  Other_Sales  Global_Sales
# 15980       0.0          0.0          0.01

# %% [markdown]
# ## Q11 retrieve the highest globalsales year which genre comes under action

# %%
genr=games.groupby(['Genre'])

# %%
gen=genr.get_group('Action')
gen
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10700\2741153656.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   gen=genr.get_group('Action')
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# ...      ...                                                ...      ...
# 16564  16567      Original Frisbee Disc Sports: Ultimate & Golf       DS
# 16567  16570  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# ...

# %%
gen.nlargest(1,'Global_Sales')
# Out:
#     Rank                Name Platform    Year   Genre             Publisher  \
# 16    17  Grand Theft Auto V      PS3  2013.0  Action  Take-Two Interactive
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 16      7.01      9.27      0.97         4.14          21.4

# %%
gen.nlargest(1,'Global_Sales')['Year']
# Out:
# 16    2013.0
# Name: Year, dtype: float64

# %% [markdown]
# ### Q12 retrieve the games that comes under the platform 'PS3'

# %%
plat=games.groupby(['Platform'])

# %%
plat.get_group('PS3')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10700\3514334872.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   plat.get_group('PS3')
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 34        35                         Call of Duty: Black Ops II      PS3
# 37        38                     Call of Duty: Modern Warfare 3      PS3
# 40        41                            Call of Duty: Black Ops      PS3
# 54        55                                     Gran Turismo 5      PS3
# ...      ...                                                ...      ...
# 16450  16453                        Hyperdimension Neptunia mk2      PS3
# 16451  16454  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3
# ...

# %%
plat.get_group('PS3')['Name']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10700\2329390583.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   plat.get_group('PS3')['Name']
# 16                                      Grand Theft Auto V
# 34                              Call of Duty: Black Ops II
# 37                          Call of Duty: Modern Warfare 3
# 40                                 Call of Duty: Black Ops
# 54                                          Gran Turismo 5
#                                ...
# 16450                          Hyperdimension Neptunia mk2
# 16451    Shin Koihime Musou: Otome Taisen * Sangokushi ...
# 16480                                  Muv-Luv Alternative
# 16521                             Akatsuki no Goei Trinity
# 16541                                      Battle Fantasia
# Name: Name, Length: 1329, dtype: object

# %% [markdown]
# ## Q13 retrive the gamename with globalsales=20.81

# %%
games[games['Global_Sales']==20.81]
# Out:
#     Rank                           Name Platform    Year   Genre  \
# 17    18  Grand Theft Auto: San Andreas      PS2  2004.0  Action
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 17  Take-Two Interactive      9.43       0.4      0.41        10.57
#
#     Global_Sales
# 17         20.81

# %%
games[games['Global_Sales']==20.81]['Name']
# Out:
# 17    Grand Theft Auto: San Andreas
# Name: Name, dtype: object

# %% [markdown]
# ## Q14 list out the publishers in 2009

# %%
games[games['Year']==2009]
# Out:
#         Rank                                  Name Platform    Year  \
# 3          4                     Wii Sports Resort      Wii  2009.0
# 8          9             New Super Mario Bros. Wii      Wii  2009.0
# 14        15                          Wii Fit Plus      Wii  2009.0
# 36        37        Call of Duty: Modern Warfare 2     X360  2009.0
# 45        46  Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0
# ...      ...                                   ...      ...     ...
# 16540  16543                               15 Days       PC  2009.0
# 16551  16554                    Sweet Honey Coming      PS2  2009.0
# 16577  16580                             Damnation       PC  2009.0
# 16586  16589        Secret Files 2: Puritas Cordis       DS  2009.0
# 16587  16590              Mezase!! Tsuri Master DS       DS  2009.0
#
#            Genre          Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 3         Sports           Nintendo     15.75     11.01      3.28
# ...

# %%
games[games['Year']==2009]['Publisher']
# Out:
# 3                 Nintendo
# 8                 Nintendo
# 14                Nintendo
# 36              Activision
# 45                Nintendo
#                ...
# 16540    DTP Entertainment
# 16551      Kadokawa Shoten
# 16577          Codemasters
# 16586          Deep Silver
# 16587          Hudson Soft
# Name: Publisher, Length: 1431, dtype: object

# %% [markdown]
# ## Q15 list out the highest ranked publisher at 2006

# %%
games[games['Year']==2006].head(1)
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
games[games['Year']==2006].head(1)['Publisher']
# Out:
# 0    Nintendo
# Name: Publisher, dtype: object
