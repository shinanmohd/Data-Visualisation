# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dir=pd.read_csv(r'C:\Users\hp\Data Analyst\csv\directors.csv')

# %%
mov=pd.read_csv(r'C:\Users\hp\Data Analyst\csv\movies.csv')

# %%
dir
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
mov
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movdir=mov.merge(dir,how='left',left_on='director_id',right_on='id')

# %%
movdir
# Out:
#       Unnamed: 0_x   id_x     budget  popularity     revenue  \
# 0                0  43597  237000000         150  2787965087
# 1                1  43598  300000000         139   961000000
# 2                2  43599  245000000         107   880674609
# 3                3  43600  250000000         112  1084939099
# 4                5  43602  258000000         115   890871626
# ...            ...    ...        ...         ...         ...
# 1460          4736  48363          0           3      321952
# 1461          4743  48370      27000          19     3151130
# 1462          4748  48375          0           7           0
# 1463          4749  48376          0           3           0
# 1464          4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movdir.drop(columns=['Unnamed: 0_y','Unnamed: 0_x','id_y'],axis=1,inplace=True)

# %%
movdir.rename(columns={'id_x':'id'},inplace=True)

# %%
movdir
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# ### Description
# Unnamed: 0: Likely an index column or a redundant ID column.
# id: The unique identifier for each movie or data entry.
# budget: The allocated budget for the movie, likely in millions.
# popularity: A measure of how popular the movie is, based on factors like views, mentions, etc.
# revenue: The total earnings or revenue the movie generated, possibly in millions.
# title: The title or name of the movie.
# vote_average: The average rating the movie received, usually out of 10 (scaled to 100 here).
# vote_count: The number of people who voted or rated the movie.
# director_id: The unique identifier for the movie's director.
# year: The year the movie was released or produced.
# month: The month the movie was released or produced.
# day: The day of the month the movie was released or produced.

# %%
movdir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  gender         1341 non-null   object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 148.9+ KB

# %%
movdir.isnull().sum()
# Out:
# id                 0
# budget             0
# popularity         0
# revenue            0
# title              0
# vote_average       0
# vote_count         0
# director_id        0
# year               0
# month              0
# day                0
# director_name      0
# gender           124
# dtype: int64

# %%
movdir.dropna(inplace=True)

# %%
movdir.isnull().sum()
# Out:
# id               0
# budget           0
# popularity       0
# revenue          0
# title            0
# vote_average     0
# vote_count       0
# director_id      0
# year             0
# month            0
# day              0
# director_name    0
# gender           0
# dtype: int64

# %%
movdir.duplicated().sum()
# Out:
# 0

# %%
movdir.describe()
# Out:
#                  id        budget   popularity       revenue  vote_average  \
# count   1341.000000  1.341000e+03  1341.000000  1.341000e+03   1341.000000
# mean   45195.272931  4.929728e+07    31.466816  1.477889e+08      6.378896
# std     1191.462551  4.997809e+07    35.599511  2.113013e+08      0.816505
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44192.000000  1.500000e+07    12.000000  1.892887e+07      5.900000
# 50%    44973.000000  3.500000e+07    23.000000  8.004976e+07      6.400000
# 75%    45959.000000  7.000000e+07    41.000000  1.839537e+08      7.000000
# max    48376.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count  director_id         year
# count   1341.000000  1341.000000  1341.000000
# mean    1184.343028  5031.985086  2002.586875
# std     1614.748836   254.186369     8.688950
# min        1.000000  4762.000000  1976.000000
# 25%      226.000000  4842.000000  1998.000000
# ...

# %%
movdir.describe().T
# Out:
#                count          mean           std      min         25%  \
# id            1341.0  4.519527e+04  1.191463e+03  43597.0     44192.0
# budget        1341.0  4.929728e+07  4.997809e+07      0.0  15000000.0
# popularity    1341.0  3.146682e+01  3.559951e+01      0.0        12.0
# revenue       1341.0  1.477889e+08  2.113013e+08      0.0  18928871.0
# vote_average  1341.0  6.378896e+00  8.165055e-01      3.0         5.9
# vote_count    1341.0  1.184343e+03  1.614749e+03      1.0       226.0
# director_id   1341.0  5.031985e+03  2.541864e+02   4762.0      4842.0
# year          1341.0  2.002587e+03  8.688950e+00   1976.0      1998.0
#
#                      50%          75%           max
# id               44973.0      45959.0  4.837600e+04
# budget        35000000.0   70000000.0  3.800000e+08
# popularity          23.0         41.0  7.240000e+02
# revenue       80049764.0  183953723.0  2.787965e+09
# vote_average         6.4          7.0  8.300000e+00
# ...

# %%
movdir
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1459  48359          0           2           0
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# ### Q1Get the top 10 rated movies

# %%
movdir.nlargest(10,'vote_average')
# Out:
#          id     budget  popularity     revenue  \
# 383   44259   63000000         146   100853753
# 901   45415   22000000         104   321365567
# 1284  46829    8000000         121   213928762
# 45    43662  185000000         187  1004558444
# 459   44406   55000000         138   677945399
# 917   45444   25000000          63    46836394
# 58    43692  165000000         724   675120017
# 59    43693  160000000         167   825532764
# 199   43926   94000000         123  1118888979
# 785   45150   33000000          79   327311859
#
#                                               title  vote_average  vote_count  \
# 383                                      Fight Club           8.3        9413
# 901                                Schindler's List           8.3        4329
# 1284                                   Pulp Fiction           8.3        8428
# 45                                  The Dark Knight           8.2       12002
# ...

# %%
titvot=movdir.nlargest(10,'vote_average')[['title','vote_average']].reset_index()

# %%
titvot
# Out:
#    index                                          title  vote_average
# 0    383                                     Fight Club           8.3
# 1    901                               Schindler's List           8.3
# 2   1284                                   Pulp Fiction           8.3
# 3     45                                The Dark Knight           8.2
# 4    459                                   Forrest Gump           8.2
# 5    917                                     GoodFellas           8.2
# 6     58                                   Interstellar           8.1
# 7     59                                      Inception           8.1
# 8    199  The Lord of the Rings: The Return of the King           8.1
# 9    785                                          Se7en           8.1

# %%
plt.figure(figsize=(10,5))
plt.plot(titvot['title'],titvot['vote_average'],marker='d',c='r')
plt.xticks(rotation=90)
plt.xlabel('Title')
plt.ylabel('VoteAverage')
plt.grid(True)
plt.title('Title over VoteAverage');

# %%
plt.figure(figsize=(10,5))
plt.plot(titvot['title'],titvot['vote_average'],marker='d',c='r')
plt.xticks(rotation=90)
plt.xlabel('Title')
plt.ylabel('VoteAverage')
plt.title('Title over VoteAverage');

# %% [markdown]
# ### Q2 retrieve the day when 'Interstellar' released

# %%
movdir.groupby(['title']).get_group('Interstellar')['day'].reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15616\3200859238.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   movdir.groupby(['title']).get_group('Interstellar')['day'].reset_index()
#    index        day
# 0     58  Wednesday

# %% [markdown]
# ### Q3 retrieve title of the film with highest vote count

# %%
movdir.nlargest(1,'vote_count')[['title','vote_count']].reset_index()
# Out:
#    index      title  vote_count
# 0     59  Inception       13752

# %% [markdown]
# ### Q4 retrieve the lowest 10 film on the basis of popularity

# %%
movdir.nsmallest(10,'popularity')['title'].reset_index()
# Out:
#    index                           title
# 0    879                 The Magic Flute
# 1   1164               Felicia's Journey
# 2   1180              Jefferson in Paris
# 3   1214                 Living Out Loud
# 4   1378            An Everlasting Piece
# 5   1431             Walking and Talking
# 6   1436                Twin Falls Idaho
# 7   1438         Everything Put Together
# 8   1440  Alleluia! The Devil's Carnival
# 9   1448                    Chuck & Buck

# %% [markdown]
# ## Q5 plot histogram on the basis Revenue feature

# %%
plt.title('Revenue Distribution')
plt.hist(movdir['revenue'],bins=5,edgecolor='black')
plt.xlabel('Revenue')
plt.show();

# %% [markdown]
# ### Q6 Retrieve the title of the 5 highest budget movies

# %%
bud=movdir.nlargest(5,'budget')

# %%
bud
# Out:
#        id     budget  popularity     revenue  \
# 12  43614  380000000         135  1045713802
# 1   43598  300000000         139   961000000
# 6   43607  270000000          57   391081192
# 4   43602  258000000         115   890871626
# 9   43610  255000000          49    89289910
#
#                                           title  vote_average  vote_count  \
# 12  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1      Pirates of the Caribbean: At World's End           6.9        4500
# 6                              Superman Returns           5.4        1400
# 4                                  Spider-Man 3           5.9        3576
# 9                               The Lone Ranger           5.9        2311
#
#     director_id  year month        day   director_name gender
# 12         4775  2011   May   Saturday    Rob Marshall   Male
# 1          4763  2007   May   Saturday  Gore Verbinski   Male
# ...

# %%
plt.bar(bud['title'],bud['budget'])
plt.xticks(rotation=90);

# %% [markdown]
# ### Q7 listout the movies released inbetween 2009 to 2012

# %%
movdir[(movdir['year']>=2009) & (movdir['year']<=2012)]
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 3     43600  250000000         112  1084939099
# 12    43614  380000000         135  1045713802
# 13    43615  225000000          52   624026776
# 15    43618  200000000          37   310669540
# ...     ...        ...         ...         ...
# 1393  47524    3000000           5           0
# 1417  47821    1500000          58    97009150
# 1434  48068          0           5           0
# 1452  48274          0           5     2611555
# 1462  48375          0           7           0
#
#                                             title  vote_average  vote_count  \
# 0                                          Avatar           7.2       11800
# 3                           The Dark Knight Rises           7.6        9106
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 13                                 Men in Black 3           6.2        4160
# ...

# %% [markdown]
# ### Q8 Find the average revenue of the films that was released on 2010 january

# %%
year2010=movdir.groupby(['year']).get_group(2010)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15616\1282877157.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   year2010=movdir.groupby(['year']).get_group(2010)

# %%
jan2010=year2010[year2010['month']=='Jan']
jan2010
# Out:
#          id    budget  popularity   revenue              title  vote_average  \
# 429   44355  80000000          24  74901339   Edge of Darkness           6.2
# 860   45330  28000000          14  45236543  The Spy Next Door           5.5
# 1393  47524   3000000           5         0        Please Give           6.0
#
#       vote_count  director_id  year month     day      director_name  gender
# 429          487         4791  2010   Jan  Friday    Martin Campbell    Male
# 860          345         5116  2010   Jan  Friday       Brian Levant    Male
# 1393          57         6204  2010   Jan  Friday  Nicole Holofcener  Female

# %%
jan2010['revenue'].mean()
# Out:
# 40045960.666666664

# %% [markdown]
# ### Q9 plot a graph that shows the features voteaverage and votecount of top 10 rated movies

# %%
top=movdir.nlargest(10,'vote_average')
top
# Out:
#          id     budget  popularity     revenue  \
# 383   44259   63000000         146   100853753
# 901   45415   22000000         104   321365567
# 1284  46829    8000000         121   213928762
# 45    43662  185000000         187  1004558444
# 459   44406   55000000         138   677945399
# 917   45444   25000000          63    46836394
# 58    43692  165000000         724   675120017
# 59    43693  160000000         167   825532764
# 199   43926   94000000         123  1118888979
# 785   45150   33000000          79   327311859
#
#                                               title  vote_average  vote_count  \
# 383                                      Fight Club           8.3        9413
# 901                                Schindler's List           8.3        4329
# 1284                                   Pulp Fiction           8.3        8428
# 45                                  The Dark Knight           8.2       12002
# ...

# %%
plt.plot(top['vote_average'],top['vote_count'],marker='d')
plt.xlabel('voteaverage')
plt.ylabel('votecount');

# %% [markdown]
# ## Q10 retrieve the count of the movies according to director

# %%
movdir['director_name'].value_counts().head(10).plot(kind='bar',colormap='magma',ylabel='counts',title='director over moviecout',grid=True);

# %%
movdir.groupby(['director_name'])['revenue'].sum().reset
# Out:
# director_name
# Adam McKay                      859076455
# Adam Shankman                   873562773
# Alejandro González Iñárritu     877979871
# Alex Proyas                     774562458
# Andrew Adamson                 2606859447
#                                   ...
# Wes Craven                      764794281
# Wolfgang Petersen              1615016083
# Woody Allen                     620906323
# Zack Snyder                    2476197387
# Zhang Yimou                     365569811
# Name: revenue, Length: 181, dtype: int64
